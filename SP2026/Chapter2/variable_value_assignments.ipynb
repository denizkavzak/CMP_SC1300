# %%
# tax_rate = 0.5
taxRate = 0.5 # initial value of tax rate

print(taxRate) # print tax rate

taxRate = 100

print(taxRate)

taxRate = "Tax_rate String text"

print(taxRate)
# Out:
# 0.5
# 100
# Tax_rate String text

# %%
num1 = 5
num2 = 10
num3 = 100
multiplication = 1
multiplication = multiplication * num1
multiplication = multiplication * num2
multiplication = multiplication * num3
print(multiplication)
# Out:
# 5000

# %%
#
#
#
#
#
#

# %%
num1 = 5
num2 = 10
num3 = 15
sum = 0
print(sum)
sum = sum + num1
print(sum)
sum = sum + num2
print(sum)
sum = sum + num3
print(sum)
# Out:
# 0
# 5
# 15
# 30
