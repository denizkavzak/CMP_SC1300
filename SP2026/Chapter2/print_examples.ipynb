# %%
x = 10
y = 20
print(x+y)
average = (x+y)/2
print(average)
# Out:
# 30
# 15.0

# %%
print("Hello")
# Out:
# Hello

# %%
string1 = "Hello"
print(string1)
# Out:
# Hello

# %%
a = 5.65
print(a)
# Out:
# 5.65

# %%
char1 = 'H'
print(char1)
# Out:
# H

# %%
x = 10
y = 15
print(x+y)
# Out:
# 25
