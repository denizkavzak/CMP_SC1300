# %%
num1 = 10
num2 = 20
num3 = 2
result = num1 // num2 // num3
print(result)
# Out:
# 0

# %%
num1 = 20
num2 = 10
num3 = 2
result = num1 // num2 // num3
print(result)
# Out:
# 1

# %%
num1 = 20
num2 = 10
num3 = 2
result = num1 // num2 / num3
print(result)
# Out:
# 1.0

# %%
num1 = 20
num2 = 10
num3 = 2
result = num1 / num2 // num3
print(result)
# Out:
# 1.0
