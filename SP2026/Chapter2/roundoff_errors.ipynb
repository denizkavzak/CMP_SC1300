# %%
price = 4.35
quantity = 100
total = price * quantity 
# Should be 100 * 4.35 = 435.00
print(total)
# Out:
# 434.99999999999994

# %%
print(0.1 + 0.2) # Output: 0.30000000000000004
# Out:
# 0.30000000000000004

# %%
a = 1.0000001
b = 1.0000000
print(a - b) # Output: 1.0000000005838672e-07
# Out:
# 1.0000000005838672e-07

# %%
decimal_number = 0.1
print(f"{decimal_number:.30f}") # Output: 0.100000000000000005551115123126
# Out:
# 0.100000000000000005551115123126

# %%
total = 0.0
for _ in range(10):
    total += 0.1
print(total) # Output: 0.9999999999999999 (not 1.0)
# Out:
# 0.9999999999999999

# %%
print(1e308 * 10) # Output: inf (overflow)
print(1e-324 / 10) # Output: 0.0 (underflow)
# Out:
# inf
# 0.0

# %%
print(0.1 + 0.2 == 0.3) # Output: False
# Out:
# False

# %%
print(1.2 - 1.0) # Output: 0.19999999999999996
# Out:
# 0.19999999999999996
