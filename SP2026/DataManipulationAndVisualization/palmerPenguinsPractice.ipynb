# %%
Using the penguins dataset:

1. Load the dataset.
2. Print the first 10 rows.
3. Find the number of rows and columns.
4. Remove rows with missing values.
5. Count how many penguins are in each species.
6. Find the average body mass for each species.
7. Make a bar chart of average body mass by species.
8. Make a scatter plot of flipper length vs body mass.
9. Write 2 observations from the plots.

# %%
pip install pandas
pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"

penguins = pd.read_csv(url)

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/allisonhorst/palmerpenguins/master/inst/extdata/penguins.csv"

df = pd.read_csv(url)

# 1. First 10 rows
print(df.head(10))

# 2. Shape
print(df.shape)

# 3. Missing values
print(df.isna().sum())

# 4. Clean data
df = df.dropna()

# 5. Count by species
print(df["species"].value_counts())

# 6. Average body mass by species
avg_mass = df.groupby("species")["body_mass_g"].mean()
print(avg_mass)

# 7. Bar chart
avg_mass.plot(kind="bar")
plt.title("Average Body Mass by Species")
plt.xlabel("Species")
plt.ylabel("Body Mass (g)")
plt.show()

# 8. Scatter plot
df.plot(x="flipper_length_mm", y="body_mass_g", kind="scatter")
plt.title("Flipper Length vs Body Mass")
plt.xlabel("Flipper Length (mm)")
plt.ylabel("Body Mass (g)")
plt.show()
