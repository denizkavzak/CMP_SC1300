# %%
sideLength1 = 2
volume1 = sideLength1 ** 3
print("Volume of a cube with side length: ", sideLength1, "is", volume1)

sideLength2 = 10
volume2 = sideLength2 ** 3
print("Volume of a cube with side length: ", sideLength2, "is", volume2)
# Out:
# Volume of a cube with side length length:  2 is 8
# Volume of a cube with side length length:  10 is 1000

# %%
def main():
    volume = cubeVolume(2)
    print("Volume of a cube with side length 2 is", volume)
    print("Volume of a cube with side length 10 is", cubeVolume(10))

def cubeVolume(sideLength):
    volume = sideLength ** 3
    return volume

main() # this is where the main function is called. Other functions are already defined until this point
# Out:
# Volume of a cube with side length 2 is 8
# Volume of a cube with side length 10 is 1000

# %%
def main2():
    volume = cubeVolume2(2)
    print("Volume of a cube with side length 2 is", volume)
    print("Volume of a cube with side length 10 is", cubeVolume(10))

main2()

def cubeVolume2(sideLength): # order matters! it should be defined before it is called
    volume = sideLength ** 3
    return volume
# Out:
# Volume of a cube with side length 2 is 8
# Volume of a cube with side length 10 is 1000

# %%
def _main():
    printName("Deniz")

def printName(name):
    print("Name is: ", name)

_main()
# Out:
# Name is:  Deniz

# %%
def main3():
    isCharExist3("Text is this", "M")
    
def isCharExist3(text, charToFind):
    if text.find(charToFind) != -1: # find method returns the first index of the found char, returns -1 if not found
        print("Found it")
    else:
        return # function doesn't return a value, but we use this to exit the function
    print("Continue my code")    

main3()
