# %%
def main():
    findChar("Text is this", "M")

def findChar(textToSearch, charToFind):
    for char in textToSearch:
        if char == charToFind:
            print("Found it!")
            return # function doesn't actually return a value, but we use this return to exit the function
    print("It is not found!")

main()
# Out:
# It is not found!

# %%
def main():
    text1 = "Text is this"
    print(findChar(text1, "i")) # testing with an existing char
    print(findChar(text1, "M")) # testing with a non-existing char
    
    newText = changeChar(text1, "i", "I") # testing with an existing char
    print(newText)

    newText2 = changeChar(text1, "m", "M") # testing with a non-existing char
    print("Output is: " ,newText2)
    print(len(newText2)) # if function returns any string, this will

def findChar(textToSearch, charToFind):
    for char in textToSearch:
        if char == charToFind:
            print("Found it!")
            return True # we are returning a boolean value, so we can reuse this function
    print("It is not found!")
    return False

def changeChar(text, existingChar, changedChar):
    changedText = "" # create a new empty string to create an updated copy
    if findChar(text, existingChar) == True: # findChar(text, existingChar):
        for char in text:
            if char == existingChar:
                changedText = changedText + changedChar # changedText += changedChar
            else:
                changedText = changedText + char
            #return changedText # if we keep return here, and the code goes into else branch, function will return None
    else:
        print("The character you are searching for is not in the text you gave!")
    return changedText # putting return here makes the function return a string in any possible path

main()
# Out:
# It is not found!
# The character you are searching for is not in the text you gave!
# Output is:
# 0
