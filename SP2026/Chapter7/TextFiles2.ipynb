# %%
infiletext = open("inputTextDivider.txt", "r")

for line in infiletext:
    words = line.split() # creates a list of each word in the read line
    print(words[0].rstrip(".,?!"))

infiletext.close()
# Out:
# Deniz,36,F
# Ekin,37,M
# Robin,2,M

# %%
infiletext = open("inputTextDivider.txt", "r")

for line in infiletext:
    words = line.split(',') # creates a list of each word in the read line
    print(words[0])

infiletext.close()

# %%
inputFile = open("lyrics.txt", "r")
for line in inputFile :
    line = line.rstrip()
    wordList = line.split()
    for word in wordList :
        word = word.rstrip(".,?!")
        print(word)

inputFile.close()
# Out:
# Mary
# had
# a
# little
# lamb
# whose
# fleece
# was
# white
# as
# snow

# %%
inputFile = open("lyrics.txt", "r")

char = inputFile.read(1) # read a single character
print(char)

chars = inputFile.read(10) # read a single character
print(chars)

inputFile.close()
# Out:
# M
# ary had a

# %%
infile = open("inputRecords.txt", "r")

line = infile.readline()

while line != "" : 
    name = line.split()
    print(name)
    print()
    line = infile.readline()
    
infile.close()
# Out:
# ['China', '1330044605']
#
# ['India', '1147995898']
#
# ['United', 'States', '303824646']

# %%
infile = open("inputRecords.txt", "r")

line = infile.readline()

while line != "" : 
    record = line.rsplit(" ",1)
    name = record[0]
    number = record[1].rstrip()
    print(name)
    print(number)
    print()
    line = infile.readline()
    
infile.close()
# Out:
# China
# 1330044605
#
# India
# 1147995898
#
# United States
# 303824646

# %%
infile = open("inputRecords.txt", "r")

line = infile.readline()

while line != "" : 
    i = 0
    print(line)
    char = line[0]
    while not line[i].isdigit():
        i = i + 1

    countryName = line[0: i-1]
    population = int(line[i : ])

    print(countryName)
    print(population)
    print()
    line = infile.readline()
    
infile.close()
# Out:
# China 1330044605
#
# China
# 1330044605
#
# India 1147995898
#
# India
# 1147995898
#
# United States 303824646
# United States
# 303824646

# %%
infile = open("inputRecords.txt", "r")

line = infile.read() # reads whole file as a single string
print(line)

words = line.split()
print(words)
    
infile.close()
# Out:
# China 1330044605
# India 1147995898
# United States 303824646
# ['China', '1330044605', 'India', '1147995898', 'United', 'States', '303824646']
